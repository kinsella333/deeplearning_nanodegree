# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([
        transforms.Resize(image_size),
        transforms.ToTensor()
    ])
    
    data = datasets.ImageFolder(data_dir, transform=transform)
    
    return torch.utils.data.DataLoader(dataset=data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    
    min, max = feature_range
    return x * (max-min)+min

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(0.9216)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()
        
        self.conv_dim = conv_dim     
        
        self.conv1 = nn.Conv2d(3, conv_dim, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv2 = nn.Conv2d(conv_dim, conv_dim*2, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv3 = nn.Conv2d(conv_dim*2, conv_dim*4, kernel_size=4, stride=2, padding=1, bias=False)
        self.conv4 = nn.Conv2d(conv_dim*4, conv_dim*8, kernel_size=4, stride=2, padding=1, bias=False)
        
        self.bn2 = nn.BatchNorm2d(conv_dim*2)
        self.bn3 = nn.BatchNorm2d(conv_dim*4)
        self.bn4 = nn.BatchNorm2d(conv_dim*8)
        
        self.fc1 = nn.Linear(conv_dim*4*4*2, 1)

        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        x = F.leaky_relu(self.conv1(x), 0.2)
        x = F.leaky_relu(self.bn2(self.conv2(x)), 0.2)
        x = F.leaky_relu(self.bn3(self.conv3(x)), 0.2)
        x = F.leaky_relu(self.bn4(self.conv4(x)), 0.2)
        
        out = x.view(-1, self.conv_dim*4*4*2)
        return self.fc1(out)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_c, out_c, k_size, stride, padding, batch_norm):
    layers = []
    
    layers.append(nn.ConvTranspose2d(in_c, out_c, k_size, stride, padding, bias=False))
    
    if batch_norm: layers.append(nn.BatchNorm2d(out_c))
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        self.conv_dim = conv_dim 
        self.fc = nn.Linear(z_size, conv_dim*4*4*4)
        
        self.deconv1 = deconv(conv_dim*4, conv_dim*2, 4, 2, 1, True)
        self.deconv2 = deconv(conv_dim*2, conv_dim, 4, 2, 1, True)
        self.deconv3 = deconv(conv_dim, 3, 4, 2, 1, False)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        x = self.fc(x)
        
        x = x.view(-1, self.conv_dim*4, 4, 4)
        x = F.relu(self.deconv1(x))
        x = F.relu(self.deconv2(x))
        
        return F.tanh(self.deconv3(x))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Linear') != -1 or classname.find('Conv') != -1:
        nn.init.normal_(m.weight.data, 0, 0.02)
    if hasattr(m,'bias') and m.bias is not None:
        m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv3): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (conv4): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=1024, out_features=1, bias=True)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=2048, bias=True)
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    if smooth: labels = torch.ones(batch_size)*0.9
    else: labels = torch.ones(batch_size)
        
    if train_on_gpu: labels = labels.cuda()
        
    criterion = nn.BCEWithLogitsLoss()
    return criterion(D_out.squeeze(), labels)

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    
    if train_on_gpu: labels = labels.cuda()

    
    criterion = nn.BCEWithLogitsLoss() 
    return criterion(D_out.squeeze(), labels)

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

lr = 0.001

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, betas=(0.3, 0.999))
g_optimizer = optim.Adam(G.parameters(), lr, betas=(0.3, 0.999))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            
            d_optimizer.zero_grad()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            if train_on_gpu: real_images = real_images.cuda()
            D_real = D(real_images)
            d_real_loss = real_loss(D_real, smooth=True)
            
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu: z = z.cuda()
            fake_images = G(z)
            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1,1,size=(batch_size,z_size))
            z = torch.from_numpy(z).float()
            
            if train_on_gpu: z = z.cuda()
            fake_images = G(z)
            
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 30


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.4268 | g_loss: 1.1986
# Epoch [    1/   30] | d_loss: 0.7470 | g_loss: 2.6240
# Epoch [    1/   30] | d_loss: 1.4770 | g_loss: 1.1207
# Epoch [    1/   30] | d_loss: 1.2720 | g_loss: 1.0396
# Epoch [    1/   30] | d_loss: 1.3078 | g_loss: 1.6181
# Epoch [    1/   30] | d_loss: 1.2050 | g_loss: 1.5670
# Epoch [    1/   30] | d_loss: 1.2189 | g_loss: 1.1956
# Epoch [    1/   30] | d_loss: 1.1745 | g_loss: 1.3587
# Epoch [    1/   30] | d_loss: 1.4379 | g_loss: 0.9083
# Epoch [    1/   30] | d_loss: 1.2023 | g_loss: 1.1346
# Epoch [    1/   30] | d_loss: 1.2428 | g_loss: 1.2353
# Epoch [    1/   30] | d_loss: 1.1196 | g_loss: 1.3017
# Epoch [    1/   30] | d_loss: 1.4011 | g_loss: 1.4373
# Epoch [    1/   30] | d_loss: 1.2797 | g_loss: 0.9847
# Epoch [    1/   30] | d_loss: 1.2501 | g_loss: 1.0645
# Epoch [    1/   30] | d_loss: 1.2317 | g_loss: 1.2765
# Epoch [    1/   30] | d_loss: 1.3648 | g_loss: 1.2203
# Epoch [    1/   30] | d_loss: 1.0767 | g_loss: 0.9958
# Epoch [    1/   30] | d_loss: 1.1437 | g_loss: 0.8849
# Epoch [    1/   30] | d_loss: 1.3071 | g_loss: 1.7717
# Epoch [    1/   30] | d_loss: 1.2931 | g_loss: 1.6958
# Epoch [    1/   30] | d_loss: 1.1325 | g_loss: 1.3110
# Epoch [    1/   30] | d_loss: 1.2101 | g_loss: 1.3044
# Epoch [    1/   30] | d_loss: 1.1254 | g_loss: 0.8396
# Epoch [    1/   30] | d_loss: 0.9817 | g_loss: 1.1814
# Epoch [    1/   30] | d_loss: 1.1906 | g_loss: 1.3850
# Epoch [    1/   30] | d_loss: 1.3640 | g_loss: 1.6696
# Epoch [    1/   30] | d_loss: 1.1634 | g_loss: 0.8788
# Epoch [    1/   30] | d_loss: 1.1565 | g_loss: 1.5149
# Epoch [    1/   30] | d_loss: 1.0661 | g_loss: 0.9522
# Epoch [    1/   30] | d_loss: 1.1795 | g_loss: 0.8520
# Epoch [    1/   30] | d_loss: 1.2052 | g_loss: 2.0901
# Epoch [    1/   30] | d_loss: 1.2171 | g_loss: 1.0488
# Epoch [    1/   30] | d_loss: 1.1448 | g_loss: 1.0721
# Epoch [    1/   30] | d_loss: 1.2321 | g_loss: 1.9417
# Epoch [    1/   30] | d_loss: 0.9666 | g_loss: 1.3763
# Epoch [    1/   30] | d_loss: 1.2907 | g_loss: 2.0917
# Epoch [    1/   30] | d_loss: 1.3301 | g_loss: 1.6296
# Epoch [    1/   30] | d_loss: 0.9826 | g_loss: 1.7737
# Epoch [    1/   30] | d_loss: 0.8933 | g_loss: 1.8030
# Epoch [    1/   30] | d_loss: 0.9617 | g_loss: 1.3358
# Epoch [    1/   30] | d_loss: 1.1701 | g_loss: 1.1965
# Epoch [    1/   30] | d_loss: 1.0990 | g_loss: 1.1700
# Epoch [    1/   30] | d_loss: 1.2964 | g_loss: 0.6709
# Epoch [    1/   30] | d_loss: 1.1805 | g_loss: 1.5201
# Epoch [    1/   30] | d_loss: 1.0317 | g_loss: 1.3108
# Epoch [    1/   30] | d_loss: 1.0586 | g_loss: 1.5595
# Epoch [    1/   30] | d_loss: 1.0147 | g_loss: 1.3109
# Epoch [    1/   30] | d_loss: 1.5147 | g_loss: 1.6586
# Epoch [    1/   30] | d_loss: 1.4377 | g_loss: 0.8537
# Epoch [    1/   30] | d_loss: 1.2730 | g_loss: 1.5475
# Epoch [    1/   30] | d_loss: 0.9184 | g_loss: 1.0381
# Epoch [    1/   30] | d_loss: 1.2034 | g_loss: 2.9411
# Epoch [    1/   30] | d_loss: 0.9434 | g_loss: 1.0580
# Epoch [    1/   30] | d_loss: 0.9675 | g_loss: 1.6173
# Epoch [    1/   30] | d_loss: 1.1861 | g_loss: 1.6479
# Epoch [    1/   30] | d_loss: 1.1071 | g_loss: 1.3866
# Epoch [    2/   30] | d_loss: 1.4496 | g_loss: 1.9419
# Epoch [    2/   30] | d_loss: 0.7336 | g_loss: 2.0132
# Epoch [    2/   30] | d_loss: 0.9258 | g_loss: 1.2562
# Epoch [    2/   30] | d_loss: 1.2445 | g_loss: 2.2303
# Epoch [    2/   30] | d_loss: 1.1077 | g_loss: 0.9014
# Epoch [    2/   30] | d_loss: 1.2788 | g_loss: 0.8607
# Epoch [    2/   30] | d_loss: 0.9580 | g_loss: 1.7249
# Epoch [    2/   30] | d_loss: 1.0091 | g_loss: 1.4745
# Epoch [    2/   30] | d_loss: 0.6987 | g_loss: 2.2753
# Epoch [    2/   30] | d_loss: 1.4188 | g_loss: 0.8786
# Epoch [    2/   30] | d_loss: 0.5899 | g_loss: 1.5932
# Epoch [    2/   30] | d_loss: 0.7893 | g_loss: 0.8723
# Epoch [    2/   30] | d_loss: 0.9871 | g_loss: 1.5744
# Epoch [    2/   30] | d_loss: 1.1671 | g_loss: 1.3240
# Epoch [    2/   30] | d_loss: 1.0627 | g_loss: 1.2901
# Epoch [    2/   30] | d_loss: 0.7564 | g_loss: 1.3742
# Epoch [    2/   30] | d_loss: 0.9976 | g_loss: 1.8380
# Epoch [    2/   30] | d_loss: 1.2112 | g_loss: 2.4280
# Epoch [    2/   30] | d_loss: 1.1424 | g_loss: 1.7217
# Epoch [    2/   30] | d_loss: 1.4450 | g_loss: 1.6201
# Epoch [    2/   30] | d_loss: 1.0688 | g_loss: 1.9527
# Epoch [    2/   30] | d_loss: 1.0077 | g_loss: 1.3676
# Epoch [    2/   30] | d_loss: 0.8872 | g_loss: 0.9552
# Epoch [    2/   30] | d_loss: 0.9188 | g_loss: 2.0545
# Epoch [    2/   30] | d_loss: 0.8360 | g_loss: 1.1974
# Epoch [    2/   30] | d_loss: 1.1623 | g_loss: 2.1619
# Epoch [    2/   30] | d_loss: 1.3798 | g_loss: 1.1986
# Epoch [    2/   30] | d_loss: 1.1580 | g_loss: 1.0065
# Epoch [    2/   30] | d_loss: 0.7269 | g_loss: 1.6075
# Epoch [    2/   30] | d_loss: 0.8221 | g_loss: 2.3831
# Epoch [    2/   30] | d_loss: 0.9135 | g_loss: 2.1734
# Epoch [    2/   30] | d_loss: 1.0407 | g_loss: 2.0862
# Epoch [    2/   30] | d_loss: 1.0594 | g_loss: 2.5533
# Epoch [    2/   30] | d_loss: 0.7211 | g_loss: 1.2496
# Epoch [    2/   30] | d_loss: 0.8400 | g_loss: 1.0281
# Epoch [    2/   30] | d_loss: 0.7547 | g_loss: 2.0434
# Epoch [    2/   30] | d_loss: 0.8508 | g_loss: 1.4311
# Epoch [    2/   30] | d_loss: 0.8218 | g_loss: 2.4409
# Epoch [    2/   30] | d_loss: 0.7942 | g_loss: 0.9563
# Epoch [    2/   30] | d_loss: 0.8718 | g_loss: 2.3100
# Epoch [    2/   30] | d_loss: 0.7568 | g_loss: 1.8315
# Epoch [    2/   30] | d_loss: 0.9930 | g_loss: 1.5707
# Epoch [    2/   30] | d_loss: 1.0954 | g_loss: 2.6472
# Epoch [    2/   30] | d_loss: 0.9576 | g_loss: 3.5253
# Epoch [    2/   30] | d_loss: 0.7516 | g_loss: 1.3175
# Epoch [    2/   30] | d_loss: 1.0119 | g_loss: 1.2487
# Epoch [    2/   30] | d_loss: 0.8782 | g_loss: 1.5611
# Epoch [    2/   30] | d_loss: 0.9648 | g_loss: 1.9221
# Epoch [    2/   30] | d_loss: 0.8605 | g_loss: 1.5453
# Epoch [    2/   30] | d_loss: 0.8953 | g_loss: 0.5133
# Epoch [    2/   30] | d_loss: 0.5625 | g_loss: 1.6646
# Epoch [    2/   30] | d_loss: 1.3279 | g_loss: 1.2015
# Epoch [    2/   30] | d_loss: 0.8383 | g_loss: 2.6722
# Epoch [    2/   30] | d_loss: 0.7810 | g_loss: 1.2481
# Epoch [    2/   30] | d_loss: 0.7472 | g_loss: 1.4781
# Epoch [    2/   30] | d_loss: 1.1634 | g_loss: 3.4238
# Epoch [    2/   30] | d_loss: 1.0017 | g_loss: 3.3764
# Epoch [    3/   30] | d_loss: 1.5327 | g_loss: 1.3418
# Epoch [    3/   30] | d_loss: 1.5065 | g_loss: 0.9601
# Epoch [    3/   30] | d_loss: 0.9536 | g_loss: 2.9960
# Epoch [    3/   30] | d_loss: 0.7739 | g_loss: 2.8093
# Epoch [    3/   30] | d_loss: 0.6334 | g_loss: 2.1230
# Epoch [    3/   30] | d_loss: 0.8925 | g_loss: 3.5146
# Epoch [    3/   30] | d_loss: 0.8213 | g_loss: 2.9518
# Epoch [    3/   30] | d_loss: 0.7480 | g_loss: 3.0667
# Epoch [    3/   30] | d_loss: 0.6424 | g_loss: 1.9475
# Epoch [    3/   30] | d_loss: 1.0322 | g_loss: 1.8628
# Epoch [    3/   30] | d_loss: 0.7067 | g_loss: 2.8893
# Epoch [    3/   30] | d_loss: 0.8644 | g_loss: 1.0918
# Epoch [    3/   30] | d_loss: 0.8201 | g_loss: 1.8788
# Epoch [    3/   30] | d_loss: 0.8583 | g_loss: 3.7680
# Epoch [    3/   30] | d_loss: 1.0804 | g_loss: 2.9349
# Epoch [    3/   30] | d_loss: 1.0165 | g_loss: 1.7552
# Epoch [    3/   30] | d_loss: 0.7086 | g_loss: 2.7598
# Epoch [    3/   30] | d_loss: 0.5389 | g_loss: 1.9374
# Epoch [    3/   30] | d_loss: 0.6089 | g_loss: 1.7714
# Epoch [    3/   30] | d_loss: 1.1852 | g_loss: 1.4076
# Epoch [    3/   30] | d_loss: 0.8018 | g_loss: 0.9629
# Epoch [    3/   30] | d_loss: 1.0743 | g_loss: 4.1501
# Epoch [    3/   30] | d_loss: 0.9496 | g_loss: 3.7779
# Epoch [    3/   30] | d_loss: 0.7158 | g_loss: 2.5083
# Epoch [    3/   30] | d_loss: 0.8001 | g_loss: 1.6927
# Epoch [    3/   30] | d_loss: 0.9910 | g_loss: 2.7838
# Epoch [    3/   30] | d_loss: 1.2295 | g_loss: 1.1436
# Epoch [    3/   30] | d_loss: 1.2342 | g_loss: 2.8709
# Epoch [    3/   30] | d_loss: 0.6457 | g_loss: 3.3971
# Epoch [    3/   30] | d_loss: 1.1918 | g_loss: 3.5190
# Epoch [    3/   30] | d_loss: 1.1114 | g_loss: 1.3360
# Epoch [    3/   30] | d_loss: 0.6538 | g_loss: 3.6502
# Epoch [    3/   30] | d_loss: 0.6900 | g_loss: 2.4485
# Epoch [    3/   30] | d_loss: 0.5937 | g_loss: 1.4925
# Epoch [    3/   30] | d_loss: 1.0627 | g_loss: 3.6908
# Epoch [    3/   30] | d_loss: 0.5630 | g_loss: 3.5752
# Epoch [    3/   30] | d_loss: 0.7379 | g_loss: 2.4941
# Epoch [    3/   30] | d_loss: 0.6816 | g_loss: 3.3678
# Epoch [    3/   30] | d_loss: 1.1140 | g_loss: 1.1553
# Epoch [    3/   30] | d_loss: 1.2911 | g_loss: 3.9266
# Epoch [    3/   30] | d_loss: 0.6935 | g_loss: 2.4364
# Epoch [    3/   30] | d_loss: 0.6786 | g_loss: 3.5305
# Epoch [    3/   30] | d_loss: 0.9798 | g_loss: 2.4252
# Epoch [    3/   30] | d_loss: 0.8677 | g_loss: 2.5015
# Epoch [    3/   30] | d_loss: 0.7118 | g_loss: 2.7240
# Epoch [    3/   30] | d_loss: 1.0611 | g_loss: 1.3052
# Epoch [    3/   30] | d_loss: 0.8802 | g_loss: 1.1516
# Epoch [    3/   30] | d_loss: 1.5916 | g_loss: 1.0840
# Epoch [    3/   30] | d_loss: 1.0172 | g_loss: 3.9879
# Epoch [    3/   30] | d_loss: 0.6885 | g_loss: 2.5200
# Epoch [    3/   30] | d_loss: 0.9074 | g_loss: 1.0825
# Epoch [    3/   30] | d_loss: 0.9102 | g_loss: 2.0072
# Epoch [    3/   30] | d_loss: 0.5465 | g_loss: 2.5998
# Epoch [    3/   30] | d_loss: 0.7724 | g_loss: 3.2738
# Epoch [    3/   30] | d_loss: 0.7980 | g_loss: 2.4611
# Epoch [    3/   30] | d_loss: 0.5933 | g_loss: 1.2950
# Epoch [    3/   30] | d_loss: 0.5115 | g_loss: 2.8429
# Epoch [    4/   30] | d_loss: 0.6011 | g_loss: 3.2545
# Epoch [    4/   30] | d_loss: 0.8201 | g_loss: 2.0919
# Epoch [    4/   30] | d_loss: 0.9741 | g_loss: 1.8043
# Epoch [    4/   30] | d_loss: 0.6258 | g_loss: 1.2775
# Epoch [    4/   30] | d_loss: 0.5803 | g_loss: 2.3706
# Epoch [    4/   30] | d_loss: 1.5017 | g_loss: 4.3785
# Epoch [    4/   30] | d_loss: 0.6738 | g_loss: 2.8425
# Epoch [    4/   30] | d_loss: 0.5859 | g_loss: 2.6704
# Epoch [    4/   30] | d_loss: 0.6610 | g_loss: 2.3521
# Epoch [    4/   30] | d_loss: 1.2787 | g_loss: 1.2952
# Epoch [    4/   30] | d_loss: 0.8611 | g_loss: 1.3805
# Epoch [    4/   30] | d_loss: 1.0422 | g_loss: 2.8746
# Epoch [    4/   30] | d_loss: 0.5821 | g_loss: 2.4772
# Epoch [    4/   30] | d_loss: 0.7228 | g_loss: 1.4435
# Epoch [    4/   30] | d_loss: 0.6873 | g_loss: 3.3280
# Epoch [    4/   30] | d_loss: 1.3587 | g_loss: 4.5503
# Epoch [    4/   30] | d_loss: 0.5518 | g_loss: 1.5039
# Epoch [    4/   30] | d_loss: 0.6203 | g_loss: 2.9227
# Epoch [    4/   30] | d_loss: 0.7624 | g_loss: 1.8437
# Epoch [    4/   30] | d_loss: 0.6687 | g_loss: 2.5486
# Epoch [    4/   30] | d_loss: 0.5570 | g_loss: 2.4062
# Epoch [    4/   30] | d_loss: 0.8116 | g_loss: 5.0218
# Epoch [    4/   30] | d_loss: 1.2830 | g_loss: 1.7637
# Epoch [    4/   30] | d_loss: 0.7532 | g_loss: 2.7947
# Epoch [    4/   30] | d_loss: 0.4905 | g_loss: 3.3884
# Epoch [    4/   30] | d_loss: 1.3295 | g_loss: 0.9862
# Epoch [    4/   30] | d_loss: 0.6632 | g_loss: 3.0661
# Epoch [    4/   30] | d_loss: 0.6427 | g_loss: 2.3444
# Epoch [    4/   30] | d_loss: 0.7155 | g_loss: 3.0800
# Epoch [    4/   30] | d_loss: 0.5119 | g_loss: 3.7126
# Epoch [    4/   30] | d_loss: 0.5332 | g_loss: 2.9256
# Epoch [    4/   30] | d_loss: 0.6226 | g_loss: 2.4279
# Epoch [    4/   30] | d_loss: 0.6046 | g_loss: 1.6395
# Epoch [    4/   30] | d_loss: 0.5721 | g_loss: 2.0504
# Epoch [    4/   30] | d_loss: 0.5435 | g_loss: 2.4514
# Epoch [    4/   30] | d_loss: 0.8419 | g_loss: 2.2916
# Epoch [    4/   30] | d_loss: 0.4795 | g_loss: 3.8653
# Epoch [    4/   30] | d_loss: 0.6590 | g_loss: 2.4844
# Epoch [    4/   30] | d_loss: 0.6690 | g_loss: 2.1091
# Epoch [    4/   30] | d_loss: 0.5479 | g_loss: 2.5587
# Epoch [    4/   30] | d_loss: 0.4192 | g_loss: 2.1794
# Epoch [    4/   30] | d_loss: 0.6036 | g_loss: 3.1626
# Epoch [    4/   30] | d_loss: 0.8159 | g_loss: 2.3050
# Epoch [    4/   30] | d_loss: 0.4895 | g_loss: 2.6428
# Epoch [    4/   30] | d_loss: 0.5152 | g_loss: 2.1942
# Epoch [    4/   30] | d_loss: 0.7667 | g_loss: 2.5984
# Epoch [    4/   30] | d_loss: 0.7069 | g_loss: 3.8297
# Epoch [    4/   30] | d_loss: 0.6601 | g_loss: 1.5535
# Epoch [    4/   30] | d_loss: 0.4954 | g_loss: 2.4561
# Epoch [    4/   30] | d_loss: 0.7352 | g_loss: 2.6454
# Epoch [    4/   30] | d_loss: 0.9009 | g_loss: 1.4837
# Epoch [    4/   30] | d_loss: 0.5447 | g_loss: 3.2263
# Epoch [    4/   30] | d_loss: 0.7455 | g_loss: 3.9470
# Epoch [    4/   30] | d_loss: 0.5818 | g_loss: 3.4052
# Epoch [    4/   30] | d_loss: 0.9069 | g_loss: 2.5533
# Epoch [    4/   30] | d_loss: 0.9658 | g_loss: 3.2434
# Epoch [    4/   30] | d_loss: 0.5635 | g_loss: 3.8760
# Epoch [    5/   30] | d_loss: 1.1438 | g_loss: 1.7004
# Epoch [    5/   30] | d_loss: 0.7083 | g_loss: 3.2154
# Epoch [    5/   30] | d_loss: 1.0929 | g_loss: 2.2335
# Epoch [    5/   30] | d_loss: 0.7617 | g_loss: 2.8540
# Epoch [    5/   30] | d_loss: 0.6653 | g_loss: 2.1088
# Epoch [    5/   30] | d_loss: 0.9455 | g_loss: 3.0578
# Epoch [    5/   30] | d_loss: 0.8404 | g_loss: 2.1087
# Epoch [    5/   30] | d_loss: 0.4481 | g_loss: 4.1769
# Epoch [    5/   30] | d_loss: 0.6490 | g_loss: 3.6071
# Epoch [    5/   30] | d_loss: 0.6139 | g_loss: 2.7670
# Epoch [    5/   30] | d_loss: 1.0486 | g_loss: 2.5166
# Epoch [    5/   30] | d_loss: 0.9185 | g_loss: 3.4407
# Epoch [    5/   30] | d_loss: 0.6525 | g_loss: 3.2791
# Epoch [    5/   30] | d_loss: 0.4840 | g_loss: 4.0212
# Epoch [    5/   30] | d_loss: 0.5652 | g_loss: 2.1632
# Epoch [    5/   30] | d_loss: 0.5162 | g_loss: 2.7720
# Epoch [    5/   30] | d_loss: 0.7041 | g_loss: 3.6615
# Epoch [    5/   30] | d_loss: 0.4448 | g_loss: 4.1709
# Epoch [    5/   30] | d_loss: 0.7888 | g_loss: 1.2373
# Epoch [    5/   30] | d_loss: 0.5201 | g_loss: 1.9711
# Epoch [    5/   30] | d_loss: 0.6117 | g_loss: 3.0639
# Epoch [    5/   30] | d_loss: 0.6242 | g_loss: 3.3283
# Epoch [    5/   30] | d_loss: 0.4404 | g_loss: 3.9393
# Epoch [    5/   30] | d_loss: 0.4846 | g_loss: 4.0982
# Epoch [    5/   30] | d_loss: 0.8220 | g_loss: 1.9489
# Epoch [    5/   30] | d_loss: 0.5405 | g_loss: 3.8342
# Epoch [    5/   30] | d_loss: 0.4748 | g_loss: 2.6969
# Epoch [    5/   30] | d_loss: 0.5280 | g_loss: 2.0688
# Epoch [    5/   30] | d_loss: 0.5824 | g_loss: 3.8266
# Epoch [    5/   30] | d_loss: 0.5552 | g_loss: 3.5816
# Epoch [    5/   30] | d_loss: 0.7879 | g_loss: 2.8494
# Epoch [    5/   30] | d_loss: 0.8596 | g_loss: 1.4365
# Epoch [    5/   30] | d_loss: 1.3664 | g_loss: 1.3727
# Epoch [    5/   30] | d_loss: 0.4651 | g_loss: 3.6145
# Epoch [    5/   30] | d_loss: 0.6160 | g_loss: 3.8819
# Epoch [    5/   30] | d_loss: 0.5996 | g_loss: 4.5684
# Epoch [    5/   30] | d_loss: 0.9220 | g_loss: 1.8564
# Epoch [    5/   30] | d_loss: 0.5707 | g_loss: 3.3171
# Epoch [    5/   30] | d_loss: 1.0831 | g_loss: 4.0642
# Epoch [    5/   30] | d_loss: 0.4058 | g_loss: 4.4171
# Epoch [    5/   30] | d_loss: 0.7619 | g_loss: 3.3838
# Epoch [    5/   30] | d_loss: 0.6363 | g_loss: 2.8341
# Epoch [    5/   30] | d_loss: 0.5319 | g_loss: 2.2166
# Epoch [    5/   30] | d_loss: 0.8938 | g_loss: 1.1451
# Epoch [    5/   30] | d_loss: 0.4543 | g_loss: 3.1847
# Epoch [    5/   30] | d_loss: 1.5986 | g_loss: 0.6898
# Epoch [    5/   30] | d_loss: 0.4375 | g_loss: 3.6367
# Epoch [    5/   30] | d_loss: 0.5003 | g_loss: 3.5656
# Epoch [    5/   30] | d_loss: 0.5383 | g_loss: 1.6520
# Epoch [    5/   30] | d_loss: 0.7439 | g_loss: 3.7203
# Epoch [    5/   30] | d_loss: 0.7528 | g_loss: 1.7069
# Epoch [    5/   30] | d_loss: 0.5819 | g_loss: 4.3776
# Epoch [    5/   30] | d_loss: 0.7764 | g_loss: 4.2161
# Epoch [    5/   30] | d_loss: 1.0241 | g_loss: 1.6914
# Epoch [    5/   30] | d_loss: 0.4532 | g_loss: 3.4661
# Epoch [    5/   30] | d_loss: 0.5441 | g_loss: 2.5294
# Epoch [    5/   30] | d_loss: 0.5690 | g_loss: 2.7435
# Epoch [    6/   30] | d_loss: 0.5545 | g_loss: 1.3255
# Epoch [    6/   30] | d_loss: 0.5638 | g_loss: 2.6210
# Epoch [    6/   30] | d_loss: 0.6587 | g_loss: 2.5192
# Epoch [    6/   30] | d_loss: 0.4678 | g_loss: 3.3169
# Epoch [    6/   30] | d_loss: 0.4005 | g_loss: 3.3791
# Epoch [    6/   30] | d_loss: 1.0027 | g_loss: 2.2839
# Epoch [    6/   30] | d_loss: 1.1769 | g_loss: 1.3989
# Epoch [    6/   30] | d_loss: 0.5701 | g_loss: 2.0098
# Epoch [    6/   30] | d_loss: 0.4556 | g_loss: 3.1603
# Epoch [    6/   30] | d_loss: 0.4045 | g_loss: 4.2093
# Epoch [    6/   30] | d_loss: 0.7183 | g_loss: 1.6991
# Epoch [    6/   30] | d_loss: 0.4654 | g_loss: 3.7362
# Epoch [    6/   30] | d_loss: 0.8249 | g_loss: 2.9352
# Epoch [    6/   30] | d_loss: 0.5589 | g_loss: 2.9736
# Epoch [    6/   30] | d_loss: 0.7310 | g_loss: 3.2669
# Epoch [    6/   30] | d_loss: 0.6176 | g_loss: 2.0894
# Epoch [    6/   30] | d_loss: 0.6872 | g_loss: 5.0584
# Epoch [    6/   30] | d_loss: 0.6042 | g_loss: 2.5476
# Epoch [    6/   30] | d_loss: 0.6688 | g_loss: 3.1503
# Epoch [    6/   30] | d_loss: 0.6314 | g_loss: 2.3653
# Epoch [    6/   30] | d_loss: 0.6135 | g_loss: 2.5730
# Epoch [    6/   30] | d_loss: 0.4636 | g_loss: 2.6840
# Epoch [    6/   30] | d_loss: 0.5144 | g_loss: 2.8901
# Epoch [    6/   30] | d_loss: 0.4946 | g_loss: 3.6161
# Epoch [    6/   30] | d_loss: 0.5172 | g_loss: 2.4769
# Epoch [    6/   30] | d_loss: 0.5680 | g_loss: 3.0332
# Epoch [    6/   30] | d_loss: 0.5570 | g_loss: 3.3104
# Epoch [    6/   30] | d_loss: 0.5093 | g_loss: 3.7980
# Epoch [    8/   30] | d_loss: 0.4582 | g_loss: 3.2859
# Epoch [    8/   30] | d_loss: 0.4322 | g_loss: 4.4929
# Epoch [    8/   30] | d_loss: 0.5839 | g_loss: 4.1923
# Epoch [    8/   30] | d_loss: 0.5111 | g_loss: 3.2048
# Epoch [    8/   30] | d_loss: 0.4381 | g_loss: 2.8555
# Epoch [    8/   30] | d_loss: 0.4728 | g_loss: 4.4060
# Epoch [    8/   30] | d_loss: 0.7779 | g_loss: 2.7009
# Epoch [    8/   30] | d_loss: 0.6373 | g_loss: 3.6481
# Epoch [    8/   30] | d_loss: 0.5210 | g_loss: 2.9083
# Epoch [    8/   30] | d_loss: 0.4354 | g_loss: 4.6388
# Epoch [    8/   30] | d_loss: 0.5386 | g_loss: 3.0352
# Epoch [    8/   30] | d_loss: 0.5030 | g_loss: 4.9466
# Epoch [    8/   30] | d_loss: 0.4988 | g_loss: 3.0119
# Epoch [    8/   30] | d_loss: 0.4146 | g_loss: 4.5023
# Epoch [    8/   30] | d_loss: 0.5665 | g_loss: 3.8911
# Epoch [    8/   30] | d_loss: 0.6598 | g_loss: 2.6750
# Epoch [    8/   30] | d_loss: 0.4353 | g_loss: 4.5842
# Epoch [    8/   30] | d_loss: 0.4175 | g_loss: 3.5736
# Epoch [    8/   30] | d_loss: 0.5896 | g_loss: 2.5249
# Epoch [    8/   30] | d_loss: 0.4683 | g_loss: 3.9143
# Epoch [    8/   30] | d_loss: 0.4158 | g_loss: 5.2374
# Epoch [    8/   30] | d_loss: 0.5899 | g_loss: 2.6742
# Epoch [    8/   30] | d_loss: 0.4582 | g_loss: 3.0650
# Epoch [    8/   30] | d_loss: 0.5096 | g_loss: 3.5971
# Epoch [    8/   30] | d_loss: 0.4623 | g_loss: 4.5344
# Epoch [    8/   30] | d_loss: 0.5620 | g_loss: 0.8067
# Epoch [    8/   30] | d_loss: 0.5183 | g_loss: 3.8867
# Epoch [    8/   30] | d_loss: 1.4707 | g_loss: 0.5166
# Epoch [    8/   30] | d_loss: 0.5193 | g_loss: 3.8458
# Epoch [    8/   30] | d_loss: 0.6080 | g_loss: 3.4537
# Epoch [    8/   30] | d_loss: 0.6078 | g_loss: 2.5536
# Epoch [    8/   30] | d_loss: 0.4240 | g_loss: 3.7858
# Epoch [    8/   30] | d_loss: 0.4718 | g_loss: 3.1580
# Epoch [    8/   30] | d_loss: 0.6271 | g_loss: 3.0713
# Epoch [    8/   30] | d_loss: 0.5328 | g_loss: 3.3072
# Epoch [    8/   30] | d_loss: 0.5024 | g_loss: 3.4605
# Epoch [    8/   30] | d_loss: 0.4462 | g_loss: 4.8851
# Epoch [    8/   30] | d_loss: 0.5240 | g_loss: 2.6446
# Epoch [    8/   30] | d_loss: 0.4907 | g_loss: 3.4266
# Epoch [    8/   30] | d_loss: 0.4672 | g_loss: 2.6544
# Epoch [    8/   30] | d_loss: 0.4283 | g_loss: 2.3884
# Epoch [    8/   30] | d_loss: 0.6271 | g_loss: 3.4584
# Epoch [    8/   30] | d_loss: 0.7166 | g_loss: 4.1614
# Epoch [    8/   30] | d_loss: 1.2005 | g_loss: 1.3178
# Epoch [    8/   30] | d_loss: 0.4283 | g_loss: 4.1096
# Epoch [    8/   30] | d_loss: 0.5350 | g_loss: 4.1951
# Epoch [    8/   30] | d_loss: 0.4520 | g_loss: 1.9574
# Epoch [    8/   30] | d_loss: 0.6434 | g_loss: 2.4222
# Epoch [    8/   30] | d_loss: 0.6017 | g_loss: 2.7826
# Epoch [    8/   30] | d_loss: 0.4693 | g_loss: 2.6020
# Epoch [    8/   30] | d_loss: 0.5080 | g_loss: 4.9575
# Epoch [    8/   30] | d_loss: 0.5836 | g_loss: 1.8850
# Epoch [    8/   30] | d_loss: 0.6342 | g_loss: 3.6821
# Epoch [    8/   30] | d_loss: 0.4671 | g_loss: 3.5752
# Epoch [    8/   30] | d_loss: 0.4189 | g_loss: 3.3258
# Epoch [    8/   30] | d_loss: 0.4317 | g_loss: 5.8841
# Epoch [    8/   30] | d_loss: 0.6251 | g_loss: 2.2936
# Epoch [    9/   30] | d_loss: 0.5770 | g_loss: 2.9937
# Epoch [    9/   30] | d_loss: 0.4165 | g_loss: 3.7732
# Epoch [    9/   30] | d_loss: 0.4205 | g_loss: 4.3430
# Epoch [    9/   30] | d_loss: 0.4121 | g_loss: 5.1198
# Epoch [    9/   30] | d_loss: 0.4099 | g_loss: 3.0811
# Epoch [    9/   30] | d_loss: 0.4552 | g_loss: 4.9577
# Epoch [    9/   30] | d_loss: 0.5106 | g_loss: 4.2209
# Epoch [    9/   30] | d_loss: 0.5770 | g_loss: 3.9943
# Epoch [    9/   30] | d_loss: 0.4288 | g_loss: 3.1375
# Epoch [    9/   30] | d_loss: 0.7438 | g_loss: 4.3295
# Epoch [    9/   30] | d_loss: 0.4325 | g_loss: 3.6962
# Epoch [    9/   30] | d_loss: 0.4267 | g_loss: 4.1936
# Epoch [    9/   30] | d_loss: 0.4920 | g_loss: 2.7639
# Epoch [    9/   30] | d_loss: 0.4177 | g_loss: 1.7764
# Epoch [    9/   30] | d_loss: 0.4223 | g_loss: 3.7902
# Epoch [    9/   30] | d_loss: 0.9150 | g_loss: 3.0230
# Epoch [    9/   30] | d_loss: 0.5672 | g_loss: 5.3927
# Epoch [    9/   30] | d_loss: 0.6042 | g_loss: 4.3962
# Epoch [    9/   30] | d_loss: 0.5770 | g_loss: 3.2230
# Epoch [    9/   30] | d_loss: 0.4467 | g_loss: 5.1321
# Epoch [    9/   30] | d_loss: 0.5078 | g_loss: 2.9749
# Epoch [    9/   30] | d_loss: 0.5501 | g_loss: 3.3944
# Epoch [    9/   30] | d_loss: 0.4571 | g_loss: 4.6085
# Epoch [    9/   30] | d_loss: 1.0092 | g_loss: 4.1857
# Epoch [    9/   30] | d_loss: 0.4593 | g_loss: 3.5696
# Epoch [    9/   30] | d_loss: 0.5423 | g_loss: 3.4514
# Epoch [    9/   30] | d_loss: 0.6708 | g_loss: 1.2951
# Epoch [    9/   30] | d_loss: 0.7363 | g_loss: 4.2618
# Epoch [    9/   30] | d_loss: 0.4869 | g_loss: 1.7066
# Epoch [    9/   30] | d_loss: 0.4564 | g_loss: 2.7027
# Epoch [    9/   30] | d_loss: 0.6133 | g_loss: 2.6961
# Epoch [    9/   30] | d_loss: 0.7180 | g_loss: 3.2448
# Epoch [    9/   30] | d_loss: 0.5508 | g_loss: 2.2707
# Epoch [    9/   30] | d_loss: 0.4479 | g_loss: 4.3574
# Epoch [    9/   30] | d_loss: 0.6020 | g_loss: 2.2527
# Epoch [    9/   30] | d_loss: 0.5961 | g_loss: 1.9131
# Epoch [    9/   30] | d_loss: 0.5422 | g_loss: 4.6066
# Epoch [    9/   30] | d_loss: 0.4043 | g_loss: 3.4468
# Epoch [    9/   30] | d_loss: 0.4976 | g_loss: 3.4622
# Epoch [    9/   30] | d_loss: 0.4440 | g_loss: 4.6743
# Epoch [    9/   30] | d_loss: 0.6030 | g_loss: 2.7213
# Epoch [    9/   30] | d_loss: 0.3824 | g_loss: 2.8403
# Epoch [    9/   30] | d_loss: 0.5823 | g_loss: 2.3179
# Epoch [    9/   30] | d_loss: 0.4506 | g_loss: 3.0487
# Epoch [    9/   30] | d_loss: 0.4842 | g_loss: 2.9194
# Epoch [    9/   30] | d_loss: 0.4036 | g_loss: 4.2210
# Epoch [    9/   30] | d_loss: 0.6818 | g_loss: 5.5835
# Epoch [    9/   30] | d_loss: 0.6025 | g_loss: 1.8185
# Epoch [    9/   30] | d_loss: 0.4081 | g_loss: 4.0276
# Epoch [    9/   30] | d_loss: 0.4901 | g_loss: 2.4961
# Epoch [    9/   30] | d_loss: 0.3750 | g_loss: 3.8591
# Epoch [    9/   30] | d_loss: 0.4927 | g_loss: 2.9788
# Epoch [    9/   30] | d_loss: 0.9999 | g_loss: 2.1644
# Epoch [    9/   30] | d_loss: 0.6772 | g_loss: 3.2087
# Epoch [    9/   30] | d_loss: 0.5711 | g_loss: 3.1972
# Epoch [    9/   30] | d_loss: 0.4222 | g_loss: 3.3964
# Epoch [    9/   30] | d_loss: 0.5552 | g_loss: 3.9113
# Epoch [   10/   30] | d_loss: 1.1451 | g_loss: 6.5181
# Epoch [   10/   30] | d_loss: 0.5546 | g_loss: 5.0691
# Epoch [   10/   30] | d_loss: 0.4194 | g_loss: 3.2909
# Epoch [   10/   30] | d_loss: 0.4383 | g_loss: 4.5128
# Epoch [   10/   30] | d_loss: 0.3891 | g_loss: 2.3857
# Epoch [   10/   30] | d_loss: 0.4069 | g_loss: 4.3389
# Epoch [   10/   30] | d_loss: 0.3834 | g_loss: 5.5307
# Epoch [   10/   30] | d_loss: 0.4086 | g_loss: 4.6960
# Epoch [   10/   30] | d_loss: 0.4530 | g_loss: 3.3765
# Epoch [   10/   30] | d_loss: 0.6117 | g_loss: 2.7292
# Epoch [   10/   30] | d_loss: 0.3822 | g_loss: 3.8119
# Epoch [   10/   30] | d_loss: 0.5452 | g_loss: 3.7079
# Epoch [   10/   30] | d_loss: 0.4438 | g_loss: 3.6137
# Epoch [   10/   30] | d_loss: 0.5396 | g_loss: 3.4433
# Epoch [   30/   30] | d_loss: 0.4277 | g_loss: 4.3700
# Epoch [   30/   30] | d_loss: 0.6176 | g_loss: 2.7454
# Epoch [   30/   30] | d_loss: 0.4061 | g_loss: 3.4836
# Epoch [   30/   30] | d_loss: 0.4138 | g_loss: 5.5971
# Epoch [   30/   30] | d_loss: 0.6277 | g_loss: 5.1887
# Epoch [   30/   30] | d_loss: 0.4932 | g_loss: 4.0125
# Epoch [   30/   30] | d_loss: 0.4391 | g_loss: 4.2072
# Epoch [   30/   30] | d_loss: 0.3709 | g_loss: 4.7504
# Epoch [   30/   30] | d_loss: 0.3899 | g_loss: 4.9044
# Epoch [   30/   30] | d_loss: 0.4217 | g_loss: 3.7178
# Epoch [   30/   30] | d_loss: 0.3916 | g_loss: 3.0086
# Epoch [   30/   30] | d_loss: 0.4229 | g_loss: 4.3985
# Epoch [   30/   30] | d_loss: 0.3613 | g_loss: 5.2156
# Epoch [   30/   30] | d_loss: 0.3927 | g_loss: 5.1247
# Epoch [   30/   30] | d_loss: 0.4015 | g_loss: 5.4899

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** First of all, they are horrifying, but also surprisingly realistic. I think a larger dataset of more varied faces would improve the model, also a large more complex network with larger layers to capture varied features would continue to improve the model. I did not find much difference in changing the number of convolutional layers in testing, so I am assuming it has more to do with the size of the layers than the number or at least a combination of the two. I chose 30 epochs for my final training and that seemed to be a sweet spot where there were still some improvements to the model though a lot of oscillations were occuring as seen in the loss graph. I am interested to do some more reading on the larger more refined facial generation models out there to see where they have made improvements.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
